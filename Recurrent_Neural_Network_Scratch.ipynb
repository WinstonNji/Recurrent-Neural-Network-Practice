# %% [markdown]
# <a href="https://colab.research.google.com/github/WinstonNji/Recurrent-Neural-Network-Practice/blob/main/Recurrent_Neural_Network_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # From Scratch Implementation

# %%
import numpy as np

# dataset — predict next value in a linear trend with noise
np.random.seed(0)
series = np.arange(50) * 0.1 + 0.3 * np.random.randn(50)

seq_len = 4
X, Y = [], []
for i in range(len(series) - seq_len):
    X.append(series[i : i + seq_len])
    Y.append(series[i + seq_len])

X = np.array(X)  # (46, 4)
Y = np.array(Y)  # (46,)

# hyperparams
input_size  = 1
hidden_size = 16
output_size = 1
lr          = 0.001
epochs      = 500
loss_tracker = []

# %%
Wxh = np.random.randn(hidden_size,input_size) * 0.01
Whh = np.random.randn(hidden_size,hidden_size) * 0.01
Why = np.random.randn(output_size,hidden_size) * 0.01

bh = np.zeros((hidden_size,1))
by = np.zeros((output_size,1))

# %%
for epoch in range(epochs):
  loss_per_epoch = 0

  for s in range(len(X)):
    h = np.zeros((hidden_size,1))
    hs = {0:h.copy()}

    for t in range(seq_len):

      # ######### FORWARD PASS #############33

      x_t = X[s,t].reshape(input_size,1)

      h = np.tanh(Wxh @ x_t + Whh @ h + bh)
      hs[t + 1] = h.copy()

    y_pred = Why @ h + by
    y_target = Y[s].reshape(output_size,1)

    loss = 0.5 * (y_pred - y_target) ** 2
    loss_per_epoch += loss.item()



    # ############ BACKPROPAGATION ############

    dWxh = np.zeros_like(Wxh)
    dWhh =  np.zeros_like(Whh)
    dWhy =  np.zeros_like(Why)
    dby = np.zeros_like(by)
    dbh = np.zeros_like(bh)

    dh_next = np.zeros((hidden_size,1))

    dy = y_pred - y_target
    dWhy += dy @ h.T
    dby += dy

    for t in reversed(range(1,seq_len+1)):
      x_t = X[s,t-1].reshape(input_size,1)

      dh  = (Why.T @ dy + dh_next) * (1 - hs[t] ** 2)

      dWhh += dh @ hs[t-1].T
      dWxh += dh @ x_t.T

      dbh += dh

      dh_next = Whh.T @ dh

    for grad in [dWxh, dWhh, dWhy, dbh, dby]:
      np.clip(grad, -1, 1, out=grad)

    Wxh -= lr * dWxh
    Whh -= lr * dWhh
    Why -= lr * dWhy
    bh -= lr * dbh
    by -= lr * dby

  loss_tracker.append( loss_per_epoch / len(X))

  if epoch % 10 == 0:
    print(f"Epoch: {epoch}, Loss: {loss_per_epoch}")
# Out:
# Epoch: 0, Loss: 196.1900413644218
# Epoch: 10, Loss: 17.434656704710825
# Epoch: 20, Loss: 10.421391274373352
# Epoch: 30, Loss: 7.03527986380864
# Epoch: 40, Loss: 5.648134161236447
# Epoch: 50, Loss: 5.145601269837778
# Epoch: 60, Loss: 4.992923755016301
# Epoch: 70, Loss: 4.95470076221429
# Epoch: 80, Loss: 4.945099359632101
# Epoch: 90, Loss: 4.938377548097206
# Epoch: 100, Loss: 4.928817271833429
# Epoch: 110, Loss: 4.916168127219437
# Epoch: 120, Loss: 4.9010705002059645
# Epoch: 130, Loss: 4.88409728628802
# Epoch: 140, Loss: 4.8656900445501305
# Epoch: 150, Loss: 4.846062456938608
# Epoch: 160, Loss: 4.825304506848966
# Epoch: 170, Loss: 4.803448076308603
# Epoch: 180, Loss: 4.780547413221057
# Epoch: 190, Loss: 4.756631006838268
# Epoch: 200, Loss: 4.7315489226805365
# Epoch: 210, Loss: 4.705134356839932
# Epoch: 220, Loss: 4.677252492616636
# Epoch: 230, Loss: 4.647842363994075
# Epoch: 240, Loss: 4.6170854946657665
# Epoch: 250, Loss: 4.585283470866411
# Epoch: 260, Loss: 4.552539590339398
# Epoch: 270, Loss: 4.518997508906472
# Epoch: 280, Loss: 4.484935669509041
# Epoch: 290, Loss: 4.450481160166547
# Epoch: 300, Loss: 4.415699346404218
# Epoch: 310, Loss: 4.380674516539536
# Epoch: 320, Loss: 4.345508868126995
# Epoch: 330, Loss: 4.310427585789961
# Epoch: 340, Loss: 4.275591591305193
# Epoch: 350, Loss: 4.241171569647239
# Epoch: 360, Loss: 4.207420477844726
# Epoch: 370, Loss: 4.173823394768011
# Epoch: 380, Loss: 4.1401775583130105
# Epoch: 390, Loss: 4.106734255216719
# Epoch: 400, Loss: 4.072298227446521
# Epoch: 410, Loss: 4.035563089936087
# Epoch: 420, Loss: 3.9989273240683576
# Epoch: 430, Loss: 3.967350505564659
# Epoch: 440, Loss: 3.947948780944414
# Epoch: 450, Loss: 3.969501745523365
# Epoch: 460, Loss: 4.085035326041098
# Epoch: 470, Loss: 4.295420539321183
# Epoch: 480, Loss: 4.59236297542641
# Epoch: 490, Loss: 4.6344085019969565

# %%
pred = []
actual = []

for i in range(len(X)):
    h = np.zeros((hidden_size,1))
    hs = {0:h.copy()}

    for t in range(seq_len):
      # ---------- FORWARD PASSS ----------
      x_t = X[i,t].reshape(1,1)

      h = np.tanh(Wxh @ x_t + Whh @ h + bh)
      hs[t+1] = h.copy()

    # --------- Compute loss ------------

    y_pred = Why @ h + by
    pred.append(y_pred.item())

    y_target = Y[i].reshape(1,1)
    actual.append(y_target.item())

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,5))

ax[0].plot(pred, label='Predicted', linestyle='--')
ax[0].plot(actual, label='Actual')
ax[0].set_title('Predicted vs actual')
ax[0].legend()

ax[1].plot(loss_tracker)
ax[1].set_title('Loss vs Epochs')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')


plt.show()

# %% [markdown]
# # Tensorflow Implementation

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.1)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Sequential

# %%
# TF expects (batch, timesteps, features)

X = X.reshape(-1,seq_len,1)

# %%
model = Sequential([
    layers.SimpleRNN(hidden_size, input_shape=(seq_len,input_size)),
    layers.Dense(output_size)
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(
    optimizer = 'adam',
    loss = 'mse',
    metrics = ['mae']
)

# %%
history = model.fit(
    X,
    Y,
    epochs = 150,
    validation_split =0.2,
    verbose = 1
)
# Out:
# Epoch 1/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 336ms/step - loss: 2.8955 - mae: 1.5196 - val_loss: 8.5356 - val_mae: 2.8888
# Epoch 2/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2.5365 - mae: 1.4125 - val_loss: 7.8367 - val_mae: 2.7648
# Epoch 3/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2.2094 - mae: 1.3021 - val_loss: 7.1864 - val_mae: 2.6443
# Epoch 4/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.9100 - mae: 1.1950 - val_loss: 6.5884 - val_mae: 2.5283
# Epoch 5/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.6591 - mae: 1.0921 - val_loss: 6.0619 - val_mae: 2.4216
# Epoch 6/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.4248 - mae: 0.9898 - val_loss: 5.5982 - val_mae: 2.3235
# Epoch 7/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.2409 - mae: 0.9026 - val_loss: 5.1848 - val_mae: 2.2324
# Epoch 8/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.0695 - mae: 0.8212 - val_loss: 4.8091 - val_mae: 2.1463
# Epoch 9/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.9372 - mae: 0.7508 - val_loss: 4.4519 - val_mae: 2.0611
# Epoch 10/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.8210 - mae: 0.6884 - val_loss: 4.1250 - val_mae: 1.9800
# Epoch 11/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.7204 - mae: 0.6425 - val_loss: 3.8269 - val_mae: 1.9030
# Epoch 12/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.6372 - mae: 0.6112 - val_loss: 3.5463 - val_mae: 1.8276
# Epoch 13/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.5757 - mae: 0.5911 - val_loss: 3.2898 - val_mae: 1.7558
# Epoch 14/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.5179 - mae: 0.5722 - val_loss: 3.0587 - val_mae: 1.6886
# Epoch 15/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.4813 - mae: 0.5654 - val_loss: 2.8496 - val_mae: 1.6255
# Epoch 16/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.4490 - mae: 0.5555 - val_loss: 2.6714 - val_mae: 1.5697
# Epoch 17/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.4245 - mae: 0.5483 - val_loss: 2.5162 - val_mae: 1.5195
# Epoch 18/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.4046 - mae: 0.5409 - val_loss: 2.3699 - val_mae: 1.4707
# Epoch 19/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.3908 - mae: 0.5345 - val_loss: 2.2272 - val_mae: 1.4214
# Epoch 20/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.3781 - mae: 0.5260 - val_loss: 2.0926 - val_mae: 1.3734
# Epoch 21/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3690 - mae: 0.5191 - val_loss: 1.9701 - val_mae: 1.3282
# Epoch 22/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3609 - mae: 0.5148 - val_loss: 1.8669 - val_mae: 1.2890
# Epoch 23/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.3527 - mae: 0.5094 - val_loss: 1.7813 - val_mae: 1.2555
# Epoch 24/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3455 - mae: 0.5028 - val_loss: 1.7106 - val_mae: 1.2273
# Epoch 25/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3362 - mae: 0.4948 - val_loss: 1.6542 - val_mae: 1.2044
# Epoch 26/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3266 - mae: 0.4861 - val_loss: 1.6054 - val_mae: 1.1843
# Epoch 27/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3162 - mae: 0.4761 - val_loss: 1.5650 - val_mae: 1.1674
# Epoch 28/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3053 - mae: 0.4660 - val_loss: 1.5307 - val_mae: 1.1530
# Epoch 29/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.2943 - mae: 0.4545 - val_loss: 1.4986 - val_mae: 1.1393
# Epoch 30/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.2835 - mae: 0.4440 - val_loss: 1.4775 - val_mae: 1.1304
# Epoch 31/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.2744 - mae: 0.4333 - val_loss: 1.4640 - val_mae: 1.1248
# Epoch 32/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.2651 - mae: 0.4224 - val_loss: 1.4471 - val_mae: 1.1175
# Epoch 33/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.2569 - mae: 0.4137 - val_loss: 1.4241 - val_mae: 1.1075
# Epoch 34/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.2497 - mae: 0.4066 - val_loss: 1.3943 - val_mae: 1.0942
# Epoch 35/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.2432 - mae: 0.3996 - val_loss: 1.3603 - val_mae: 1.0788
# Epoch 36/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.2374 - mae: 0.3938 - val_loss: 1.3316 - val_mae: 1.0657
# Epoch 37/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.2315 - mae: 0.3880 - val_loss: 1.3110 - val_mae: 1.0563
# Epoch 38/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.2265 - mae: 0.3840 - val_loss: 1.2930 - val_mae: 1.0480
# Epoch 39/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.2220 - mae: 0.3792 - val_loss: 1.2764 - val_mae: 1.0404
# Epoch 40/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.2183 - mae: 0.3751 - val_loss: 1.2629 - val_mae: 1.0342
# Epoch 41/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.2155 - mae: 0.3714 - val_loss: 1.2412 - val_mae: 1.0239
# Epoch 42/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.2123 - mae: 0.3684 - val_loss: 1.2124 - val_mae: 1.0100
# Epoch 43/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2087 - mae: 0.3648 - val_loss: 1.1856 - val_mae: 0.9969
# Epoch 44/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.2060 - mae: 0.3621 - val_loss: 1.1623 - val_mae: 0.9853
# Epoch 45/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.2033 - mae: 0.3592 - val_loss: 1.1473 - val_mae: 0.9780
# Epoch 46/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.2025 - mae: 0.3595 - val_loss: 1.1309 - val_mae: 0.9698
# Epoch 47/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2007 - mae: 0.3591 - val_loss: 1.1017 - val_mae: 0.9548
# Epoch 48/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1981 - mae: 0.3581 - val_loss: 1.0676 - val_mae: 0.9369
# Epoch 49/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1954 - mae: 0.3568 - val_loss: 1.0367 - val_mae: 0.9203
# Epoch 50/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.1920 - mae: 0.3546 - val_loss: 1.0079 - val_mae: 0.9045
# Epoch 51/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1896 - mae: 0.3530 - val_loss: 0.9781 - val_mae: 0.8880
# Epoch 52/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1870 - mae: 0.3511 - val_loss: 0.9482 - val_mae: 0.8709
# Epoch 53/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1847 - mae: 0.3497 - val_loss: 0.9159 - val_mae: 0.8521
# Epoch 54/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1822 - mae: 0.3476 - val_loss: 0.8783 - val_mae: 0.8296
# Epoch 55/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1830 - mae: 0.3481 - val_loss: 0.8444 - val_mae: 0.8089
# Epoch 56/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1814 - mae: 0.3453 - val_loss: 0.8252 - val_mae: 0.7970
# Epoch 57/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1803 - mae: 0.3442 - val_loss: 0.8123 - val_mae: 0.7889
# Epoch 58/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1793 - mae: 0.3438 - val_loss: 0.7985 - val_mae: 0.7803
# Epoch 59/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1784 - mae: 0.3435 - val_loss: 0.7827 - val_mae: 0.7703
# Epoch 60/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1777 - mae: 0.3430 - val_loss: 0.7720 - val_mae: 0.7635
# Epoch 61/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0
150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1616 - mae: 0.3321 - val_loss: 0.6057 - val_mae: 0.6498
# Epoch 125/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1614 - mae: 0.3315 - val_loss: 0.5984 - val_mae: 0.6440
# Epoch 126/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1612 - mae: 0.3306 - val_loss: 0.5918 - val_mae: 0.6386
# Epoch 127/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1611 - mae: 0.3300 - val_loss: 0.5832 - val_mae: 0.6318
# Epoch 128/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1609 - mae: 0.3293 - val_loss: 0.5650 - val_mae: 0.6170
# Epoch 129/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1615 - mae: 0.3297 - val_loss: 0.5415 - val_mae: 0.5974
# Epoch 130/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1625 - mae: 0.3294 - val_loss: 0.5217 - val_mae: 0.5804
# Epoch 131/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1645 - mae: 0.3299 - val_loss: 0.5058 - val_mae: 0.5663
# Epoch 132/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1664 - mae: 0.3306 - val_loss: 0.4955 - val_mae: 0.5570
# Epoch 133/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1676 - mae: 0.3312 - val_loss: 0.4883 - val_mae: 0.5504
# Epoch 134/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.1683 - mae: 0.3319 - val_loss: 0.4894 - val_mae: 0.5514
# Epoch 135/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.1673 - mae: 0.3317 - val_loss: 0.4985 - val_mae: 0.5599
# Epoch 136/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.1641 - mae: 0.3308 - val_loss: 0.5123 - val_mae: 0.5724
# Epoch 137/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.1621 - mae: 0.3306 - val_loss: 0.5275 - val_mae: 0.5858
# Epoch 138/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.1594 - mae: 0.3305 - val_loss: 0.5436 - val_mae: 0.5997
# Epoch 139/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.1589 - mae: 0.3313 - val_loss: 0.5643 - val_mae: 0.6172
# Epoch 140/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.1598 - mae: 0.3327 - val_loss: 0.5735 - val_mae: 0.6248
# Epoch 141/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.1591 - mae: 0.3320 - val_loss: 0.5714 - val_mae: 0.6231
# Epoch 142/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.1591 - mae: 0.3321 - val_loss: 0.5667 - val_mae: 0.6193
# Epoch 143/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.1586 - mae: 0.3317 - val_loss: 0.5582 - val_mae: 0.6122
# Epoch 144/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.1586 - mae: 0.3315 - val_loss: 0.5557 - val_mae: 0.6101
# Epoch 145/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.1580 - mae: 0.3306 - val_loss: 0.5623 - val_mae: 0.6156
# Epoch 146/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.1580 - mae: 0.3307 - val_loss: 0.5688 - val_mae: 0.6209
# Epoch 147/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.1579 - mae: 0.3305 - val_loss: 0.5718 - val_mae: 0.6234
# Epoch 148/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1579 - mae: 0.3303 - val_loss: 0.5698 - val_mae: 0.6217
# Epoch 149/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1577 - mae: 0.3299 - val_loss: 0.5627 - val_mae: 0.6158
# Epoch 150/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1571 - mae: 0.3286 - val_loss: 0.5471 - val_mae: 0.6028

# %%
pred = model.predict(X)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step

# %%
fig, axes = plt.subplots(1,2, figsize = (12,4))

axes[0].plot(pred[0:5].flatten(), label='Predicted')
axes[0].plot(Y[0:5], label = 'Actual')
axes[0].legend()
axes[0].set_title('Predicted vs Actual')


axes[1].plot(history.history['loss'])
axes[1].set_title('Loss vs Epochs')

plt.tight_layout()
plt.show()
